# %%
import PyPDF2
import requests
import numpy as np, seaborn as sns, pandas as pd
import nltk, nltk.sentiment, sklearn
import collections
# %matplotlib inline

# %%
#convert list to pd.series
#doc1_str = pd.Series([''.join(doc1)])

#Preprocessing - tokenize and lower case pdf-strings
tokenizer = nltk.tokenize.TweetTokenizer()
def preprocessing(string):
    string = string.lower()
    string = tokenizer.tokenize(string)
    return string

#Apply positive/negative sets on pdf-string
#tok_doc1 = doc1_str.apply(preprocessing)

def count_dictionary(document_elem, dictionary):
    lst = []
    for word in document_elem:
        if (word in dictionary):
            lst.append(word)
    return len(lst)

# %%
#PDF extractor script. Creates a list separated per page.
def pdf_extractor(path):
    pdf_file = open(path, 'rb')
    read_pdf = PyPDF2.PdfFileReader(pdf_file)
    number_of_pages = read_pdf.getNumPages()
    c = collections.Counter(range(number_of_pages))
    res1 = []
    for i in range(len(c)):
        page = read_pdf.getPage(i)
        page_content = page.extractText()
        res1.append(page_content)
    return res1

# %%
import requests

#Create set for negative and positive lexicon
negative = set(requests.get('http://ptrckprry.com/course/ssd/data/negative-words.txt').text.split(';;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;')[2].split('\n')[2:])
positive = set(requests.get('http://ptrckprry.com/course/ssd/data/positive-words.txt').text.split(';;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;')[2].split('\n')[2:])

# %%
bow = r'C:\Users\sebag\Documents\GitHub\SDS Group 35\Exam_Project\bow.xlsx'

pos_neg = pd.read_excel(bow, '1 FS Dictionary')

positive_cb = pos_neg.loc[pos_neg['Positive'] == 1.0]
positive_cb = set(positive_cb['Word'])
positive_cb

negative_cb = pos_neg.loc[pos_neg['Negative'] == 1.0]
negative_cb = set(negative_cb['Word'])
negative_cb
# Out:
# {'abnormally',
#  'abrupt',
#  'abundant',
#  'adverse',
#  'adversely',
#  'aggravate',
#  'aggravated',
#  'aggravating',
#  'aggravation',
#  'ailing',
#  'alarming',
#  'anxiety',
#  'arrears',
#  'bad',
#  'burdened',
#  'challenge',
#  'challenges',
#  'challenging',
#  'closure',
#  'clouded',
#  'compromised',
#  'concern',
#  'concerns',
#  'confronted',
#  'confronting',
#  'constrain',
#  'constrained',
#  'constraining',
#  'contagion',
#  'contracted',
#  'contracting',
#  'contraction',
#  'corrections',
#  'costly',
#  'damaging',
#  'danger',
#  'dangerous',
#  'declines',
#  'deep',
#  'deeply',
#  'defaults',
#  'deficient',
#  'deficits',
#  'delays',
#  'delinquencies',
#  'dented',
#  'depress',
#  'depressed',
#  'depressing',
#  'destabilising',
#  'destabilizing',
#  'deteriorate',
#  'deteriorated',
#  'deteriorating',
#  'deterioration',
#  'deteriorations',
#  'detrimental',
#  'difficult',
#  'difficulties',
#  'difficulty',
#  'disappointing',
#  'discouraging',
#  'disorderly',
#  'disrupt',
#  'disrupted',
#  'disruption',
#  'disruptions',
#  'disruptive',
#  'distortions',
#  'distress',
#  'distressed',
#  'distrust',
#  'disturbance',
#  'disturbances',
#  'doubts',
#  'downgrade',
#  'downgraded',
#  'downgrades',
#  'downgrading',
#  'downside',
#  'downswing',
#  'downturn',
#  'downward',
#  'drag',
#  'drastic',
#  'dropped',
#  'drying',
#  'endanger',
#  'erode',
#  'eroded',
#  'eroding',
#  'erosion',
#  'escalate',
#  'escalated',
#  'escalating',
#  'escalation',
#  'exacerbate',
#  'exacerbated',
#  'exacerbating',
#  'excessive',
#  'exhausted',
#  'expose',
#  'exposed',
#  'exposes',
#  'exposing',
#  'fail',
#  'failed',
#  'failing',
#  'fails',
#  'failure',
#  'failures',
#  'faltering',
#  'fear',
#  'fears',
#  'forced',
#  'fragile',
#  'fragilities',
#  'fragility',
#  'gloomy',
#  'hamper',
#  'hampered',
#  'hampering',
#  'headwinds',
#  'hinder',
#  'hindered',
#  'hindering',
#  'hinders',
#  'hurt',
#  'illiquid',
#  'illiquidity',
#  'imbalance',
#  'imbalances',
#  'impair',
#  'impaired',
#  'impairing',
#  'impairments',
#  'impede',
#  'impeded',
#  'impediments',
#  'inability',
#  'inadequate',
#  'ineffective',
#  'inefficient',
#  'insolvencies',
#  'insolvency',
#  'insolvent',
#  'instability',
#  'insufficient',
#  'insufficiently',
#  'jeopardise',
#  'jeopardised',
#  'jeopardising',
#  'jeopardize',
#  'lackluster',
#  'lacklustre',
#  'lagged',
#  'lose',
#  'losing',
#  'losses',
#  'lost',
#  'misalignments',
#  'misconduct',
#  'mispricing',
#  'negative',
#  'negatively',
#  'nervousness',
#  'nonperforming',
#  'overcapacity',
#  'overheated',
#  'overheating',
#  'overindebted',
#  'overvalued',
#  'pessimism',
#  'pessimistic',
#  'plummeted',
#  'plummeting',
#  'plunge',
#  'plunged',
#  'poor',
#  'poorer',
#  'poorly',
#  'poses',
#  'posing',
#  'problem',
#  'problematic',
#  'problems',
#  'prolonged',
#  'protectionism',
#  'protracted',
#  'questions',
#  'recession',
#  'repercussions',
#  'restructure',
#  'resurfaced',
#  'riskier',
#  'setback',
#  'setbacks',
#  'severely',
#  'severity',
#  'shaken',
#  'shortage',
#  'shortages',
#  'shortfall',
#  'shortfalls',
#  'shrank',
#  'shrink',
#  'shrinking',
#  'shrunk',
#  'slid',
#  'slide',
#  'sliding',
#  'slipped',
#  'slowdown',
#  'slowdowns',
#  'sluggish',
#  'sluggishness',
#  'slump',
#  'slumped',
#  'slumps',
#  'spill',
#  'spilled',
#  'spilling',
#  'spillover',
#  'spillovers',
#  'spiral',
#  'squeeze',
#  'squeezed',
#  'stagnant',
#  'stagnate',
#  'stagnated',
#  'stagnating',
#  'stagnation',
#  'strain',
#  'strained',
#  'strains',
#  'stresses',
#  'struggle',
#  'struggling',
#  'suffer',
#  'suffered',
#  'suffering',
#  'susceptibility',
#  'susceptible',
#  'tense',
#  'tension',
#  'tepid',
#  'threat',
#  'threaten',
#  'threatened',
#  'threatening',
#  'threats',
#  'tough',
#  'troubled',
#  'tumbling',
#  'turbulence',
#  'turbulences',
#  'turbulent',
#  'turmoil',
#  'unable',
#  'undermine',
#  'undermined',
#  'undermining',
#  'underperformance',
#  'underperformed',
#  'undesirable',
#  'unease',
#  'unemployed',
#  'unexpectedly',
#  'unfavorable',
#  'unfavourable',
#  'unresolved',
#  'unrest',
#  'unstable',
#  'unsustainable',
#  'volatile',
#  'volatility',
#  'vulnerabilities',
#  'vulnerability',
#  'vulnerable',
#  'weaken',
#  'weakened',
#  'weakening',
#  'weaker',
#  'weakest',
#  'weakness',
#  'weaknesses',
#  'worries',
#  'worrisome',
#  'worrying',
#  'worse',
#  'worsen',
#  'worsened',
#  'worsening',
#  'worst',
#  'writedowns'}

# %%
'improve' in positive_cb
# Out:
# True

# %%
import os

#Sebastian file path
basedir = r'C:\Users\sebag\Documents\GitHub\SDS Group 35\Exam_Project\Minutes_PDF'
testdir = r'C:\Users\sebag\Documents\GitHub\Exam\Test folder'

def sentiment_analysis(pos, neg, file_path):
    pos_words = []
    neg_words = []
    average_tone = []
    i = 0
    error = []
    
    for fn in os.listdir(file_path):
        try:
            print('Now treating file: ' + fn + '\nIterate: ' + str(i))
            doc = pdf_extractor(file_path + '\\' + fn)
            doc = pd.Series([''.join(doc)])
            doc = doc.apply(preprocessing)

            pos_words.append(int(count_dictionary(doc[0], pos)))
            neg_words.append(int(count_dictionary(doc[0], neg)))
            average_tone.append((pos_words[i]-neg_words[i])/len(doc[0]))
            error.append(False)  
            
            i += 1
        
        except KeyError:
            error.append(True)
            pos_words.append(np.NaN)
            neg_words.append(np.NaN)
            average_tone.append(np.NaN)
            
            i += 1
            
        #date = re.findall(r'\d+', fn)
    df = pd.DataFrame(zip(pos_words, neg_words, average_tone, error))
    return df

sent_df = sentiment_analysis(positive_cb, negative_cb, basedir)
# Out:
# Now treating file: ppp000203e.pdf
# Iterate: 0
# PdfReadWarning: Xref table not zero-indexed. ID numbers for objects will be corrected. [pdf.py:1736]
# Now treating file: ppp000322e.pdf
# Iterate: 1
# Now treating file: ppp000504e.pdf
# Iterate: 2
# Now treating file: ppp000607e.pdf
# Iterate: 3
# Now treating file: ppp000706e.pdf
# Iterate: 4
# Now treating file: ppp000816e.pdf
# Iterate: 5
# Now treating file: ppp001024e.pdf
# Iterate: 6
# Now treating file: ppp001220e.pdf
# Iterate: 7
# Now treating file: ppp010201e.pdf
# Iterate: 8
# Now treating file: ppp010326e.pdf
# Iterate: 9
# Now treating file: ppp010426e.pdf
# Iterate: 10
# Now treating file: ppp010530e.pdf
# Iterate: 11
# Now treating file: ppp010614e.pdf
# Iterate: 12
# Now treating file: ppp010705e.pdf
# Iterate: 13
# Now treating file: ppp010823e.pdf
# Iterate: 14
# Now treating file: ppp010917e.pdf
# Iterate: 15
# Now treating file: ppp011015e.pdf
# Iterate: 16
# Now treating file: ppp011108e.pdf
# Iterate: 17
# Now treating file: ppp011204e.pdf
# Iterate: 18
# Now treating file: ppp020207e.pdf
# Iterate: 19
# Now treating file: ppp020318e.pdf
# Iterate: 20
# Now treating file: ppp020425e.pdf
# Iterate: 21
# Now treating file: ppp020605e.pdf
# Iterate: 22
# Now treating file: ppp020704e.pdf
# Iterate: 23
# Now treating file: ppp020815e.pdf
# Iterate: 24
# Now treating file: ppp021016e.pdf
# Iterate: 25
# Now treating file: ppp021114e.pdf
# Iterate: 26
# Now treating file: ppp021204e.pdf
# Iterate: 27
# Now treating file: ppp030206e.pdf
# Iterate: 28
# Now treating file: ppp030317e.pdf
# Iterate: 29
# Now treating file: ppp030424e.pdf
# Iterate: 30
# Now treating file: ppp030604e.pdf
# Iterate: 31
# Now treating file: ppp030703e.pdf
# Iterate: 32
# Now treating file: ppp030814e.pdf
# Iterate: 33
# Now treating file: ppp031015e.pdf
# Iterate: 34
# Now treating file: ppp031204e.pdf
# Iterate: 35
# Now treating file: ppp040205e.pdf
# Iterate: 36
# Now treating file: ppp040331e.pdf
# Iterate: 37
# Now treating file: ppp040428e.pdf
# Iterate: 38
# Now treating file: ppp040527e.pdf
# Iterate: 39
# Now treating file: ppp040623e.pdf
# Iterate: 40
# Now treating file: ppp040819e.pdf
# Iterate: 41
# Now treating file: ppp041013e.pdf
# Iterate: 42
# Now treating file: ppp041208e.pdf
# Iterate: 43
# Now treating file: ppp050127e.pdf
# Iterate: 44
# Now treating file: ppp050314e.pdf
# Iterate: 45
# Now treating file: ppp050428e.pdf
# Iterate: 46
# Now treating file: ppp050620e.pdf
# Iterate: 47
# Now treating file: ppp050823e.pdf
# Iterate: 48
# Now treating file: ppp051019e.pdf
# Iterate: 49
# Now treating file: ppp051201e.pdf
# Iterate: 50
# Now treating file: ppp060119e.pdf
# Iterate: 51
# Now treating file: ppp060308e.pdf
# Iterate: 52
# Now treating file: ppp060427e.pdf
# Iterate: 53
# Now treating file: ppp060619e.pdf
# Iterate: 54
# Now treating file: ppp060829e.pdf
# Iterate: 55
# Now treating file: ppp061025e.pdf
# Iterate: 56
# Now treating file: ppp061214e.pdf
# Iterate: 57
# Now treating file: ppp070214e.pdf
# Iterate: 58
# Now treating file: ppp070329e.pdf
# Iterate: 59
# Now treating file: ppp070503e.pdf
# Iterate: 60
# Now treating file: ppp070619e.pdf
# Iterate: 61
# Now treating file: ppp070906e.pdf
# Iterate: 62
# Now treating file: ppp071029e.pdf
# Iterate: 63
# Now treating file: ppp071218e.pdf
# Iterate: 64
# Now treating file: ppp080212e.pdf
# Iterate: 65
# Now treating file: ppp080422e.pdf
# Iterate: 66
# Now treating file: ppp080702e.pdf
# Iterate: 67
# Now treating file: ppp080903e.pdf
# Iterate: 68
# Now treating file: ppp081008e.pdf
# Iterate: 69
# Now treating file: ppp081022e.pdf
# Iterate: 70
# Now treating file: ppp081203e.pdf
# Iterate: 71
# Now treating file: ppp090210e.pdf
# Iterate: 72
# Now treating file: ppp090420e.pdf
# Iterate: 73
# Now treating file: ppp090701e.pdf
# Iterate: 74
# Now treating file: ppp090916e.pdf
# Iterate: 75
# Now treating file: ppp091021e.pdf
# Iterate: 76
# Now treating file: ppp091215e.pdf
# Iterate: 77
# Now treating file: ppp100224e.pdf
# Iterate: 78
# Now treating file: ppp100503e.pdf
# Iterate: 79
# Now treating file: ppp100630e.pdf
# Iterate: 80
# Now treating file: ppp100901e.pdf
# Iterate: 81
# Now treating file: ppp101025e.pdf
# Iterate: 82
# Now treating file: ppp101214e.pdf
# Iterate: 83
# Now treating file: ppp110214e.pdf
# Iterate: 84
# Now treating file: ppp110419e.pdf
# Iterate: 85
# Now treating file: ppp110704e.pdf
# Iterate: 86
# Now treating file: ppp110920e.pdf
# Iterate: 87
# Now treating file: ppp111026e.pdf
# Iterate: 88
# Now treating file: ppp111219e.pdf
# Iterate: 89
# Now treating file: ppp120215e.pdf
# Iterate: 90
# Now treating file: ppp120417e.pdf
# Iterate: 91
# Now treating file: ppp120703e.pdf
# Iterate: 92
# Now treating file: ppp120905e.pdf
# Iterate: 93
# Now treating file: ppp121024e.pdf
# Iterate: 94
# Now treating file: ppp121217e.pdf
# Iterate: 95
# Now treating file: ppp130212e.pdf
# Iterate: 96
# Now treating file: ppp130429e.pdf
# Iterate: 97
# Now treating file: ppp130716e.pdf
# Iterate: 98
# Now treating file: ppp130918e.pdf
# Iterate: 99
# Now treating file: ppp131106e.pdf
# Iterate: 100
# Now treating file: ppp131216e.pdf
# Iterate: 101
# Now treating file: ppp140212e.pdf
# Iterate: 102
# Now treating file: ppp140408e.pdf
# Iterate: 103
# Now treating file: ppp140702e.pdf
# Iterate: 104
# Now treating file: ppp140917e.pdf
# Iterate: 105
# Now treating file: ppp141111e.pdf
# Iterate: 106
# Now treating file: ppp141215e.pdf
# Iterate: 107
# Now treating file: ppp150225e.pdf
# Iterate: 108
# Now treating file: ppp150511e.pdf
# Iterate: 109
# Now treating file: ppp150715e.pdf
# Iterate: 110
# Now treating file: ppp150916e.pdf
# Iterate: 111
# Now treating file: ppp151110e.pdf
# Iterate: 112
# Now treating file: ppp151214e.pdf
# Iterate: 113
# Now treating file: ppp160222e.pdf
# Iterate: 114
# Now treating file: ppp160504e.pdf
# Iterate: 115
# Now treating file: ppp160705e.pdf
# Iterate: 116
# Now treating file: ppp160906e.pdf
# Iterate: 117
# Now treating file: ppp161026e.pdf
# Iterate: 118
# Now treating file: ppp161220e.pdf
# Iterate: 119
# Now treating file: ppp170214e.pdf
# Iterate: 120
# Now treating file: ppp170426e.pdf
# Iterate: 121
# Now treating file: ppp170703e.pdf
# Iterate: 122
# Now treating file: ppp170906e.pdf
# Iterate: 123
# Now treating file: ppp171025e.pdf
# Iterate: 124
# Now treating file: ppp171219e.pdf
# Iterate: 125
# Now treating file: ppp180213e.pdf
# Iterate: 126
# Now treating file: ppp180425e.pdf
# Iterate: 127
# Now treating file: ppp180702e.pdf
# Iterate: 128
# Now treating file: ppp180905e.pdf
# Iterate: 129
# Now treating file: ppp181023e.pdf
# Iterate: 130
# Now treating file: ppp181219e.pdf
# Iterate: 131
# Now treating file: ppp190212e.pdf
# Iterate: 132
# Now treating file: ppp190424e.pdf
# Iterate: 133
# Now treating file: ppp190702e.pdf
# Iterate: 134

# %%
sent_df.columns = ['Number of positive words', 'Number of negative words', 'Average tone ratio', 'Error in processing PDF']
#print(sent_df.loc[sent_df['Number of positive words'] == True])
len(list(filter(lambda x: x > 0, sent_df['Average tone ratio'])))
sent_df
# Out:
#      Number of positive words  Number of negative words  Average tone ratio  \
# 0                          30                        35           -0.000822
# 1                          11                        19           -0.001847
# 2                          20                        25           -0.001100
# 3                          12                        21           -0.002571
# 4                          12                        28           -0.003221
# 5                          12                        21           -0.002571
# 6                           9                        30           -0.005189
# 7                          25                        50           -0.004305
# 8                          20                        95           -0.013296
# 9                          16                        55           -0.009266
# 10                         15                        47           -0.007098
# 11                         14                        43           -0.006956
# 12                          7                        12           -0.002885
# 13                         29                       104           -0.010075
# 14                         23                        89           -0.012891
# 15                         10                        37           -0.007357
# 16                         23                        60           -0.008109
# 17                          7                        27           -0.004091
# 18                         27                        54           -0.005180
# 19                         34                        93           -0.008319
# 20                         18                        32           -0.002974
# 21                         33                        51           -0.003403
# 22                         29                        33           -0.000972
# 23                         31                        78           -0.008739
# 24                         32                        53           -0.004657
# 25                         45                        64           -0.004191
# 26                         16                        42           -0.007168
# 27                         18                        29           -0.002810
# 28                         17                        43           -0.006096
# 29                         16                        59           -0.011054
# ..                        ...                       ...                 ...
# 105                        48                        82           -0.003083
# 106                        48                        88           -0.003787
# 107                        58                        80           -0.002263
# 108                        74                       160           -0.005844
# 109                        57                       118           -0.004944
# 110                        70                       110           -0.003301
# 111                        70                       117           -0.004484
# 112                        64                       102           -0.003100
# 113                        59                        81           -0.002238
# 114                        65                       160           -0.007035
# 115                        46                        67           -0.002135
# 116                        53                       105           -0.005404
# 117                        58                        91           -0.002847
# 118                        62                        91           -0.002442
# 119                        61                        94           -0.002348
# 120                        49                        66           -0.001587
# 121                        62                        76           -0.001325
# 122                        62                        67           -0.000546
# 123                        57                        93           -0.003502
# 124                        45                        95           -0.003780
# 125                        45                        51           -0.000536
# 126                        60                        99           -0.003434
# 127                        46                        95           -0.004789
# 128                        42                       132           -0.007486
# 129                        60                       108           -0.003982
# 130                        52                        70           -0.001669
# 131                        49                        68           -0.001914
# 132                        42                        73           -0.003899
# 133                        41                        90           -0.004223
# 134                        36                       108           -0.006428
#
#      Error in processing PDF
# 0                      False
# 1                      False
# 2                      False
# 3                      False
# 4                      False
# 5                      False
# 6                      False
# 7                      False
# 8                      False
# 9                      False
# 10                     False
# 11                     False
# 12                     False
# 13                     False
# 14                     False
# 15                     False
# 16                     False
# 17                     False
# 18                     False
# 19                     False
# 20                     False
# 21                     False
# 22                     False
# 23                     False
# 24                     False
# 25                     False
# 26                     False
# 27                     False
# 28                     False
# 29                     False
# ..                       ...
# 105                    False
# 106                    False
# 107                    False
# 108                    False
# 109                    False
# 110                    False
# 111                    False
# 112                    False
# 113                    False
# 114                    False
# 115                    False
# 116                    False
# 117                    False
# 118                    False
# 119                    False
# 120                    False
# 121                    False
# 122                    False
# 123                    False
# 124                    False
# 125                    False
# 126                    False
# 127                    False
# 128                    False
# 129                    False
# 130                    False
# 131                    False
# 132                    False
# 133                    False
# 134                    False
#
# [135 rows x 4 columns]

# %%
import os, re, pandas as pd, ast, datetime

#Mark file path:
path = 'C:/Users/maje.DKSUND/Desktop/SDS-Group-35-master_new/SDS-Group-35-master/Exam_Project/Minutes_PDF'

files = []
files2 = []

# r=root, d=directories, f = files
for r, d, f in os.walk(basedir):
    for file in f:
        if '.pdf' in file:
            files.append('20' + file[3:5] + "-" + file[5:7] + "-" + file[7:9])
            files2.append(file)

Final_list = {'Dato':files,'Filnavn':files2}

df_files = pd.DataFrame(Final_list)
df_files['date_time'] = pd.to_datetime(df_files['Dato'])
df_files['Date time announcement'] = pd.to_datetime(df_files['Dato']) + pd.DateOffset(days=1)
df_files
# Out:
#            Dato         Filnavn  date_time Date time announcement
# 0    2000-02-03  ppp000203e.pdf 2000-02-03             2000-02-04
# 1    2000-03-22  ppp000322e.pdf 2000-03-22             2000-03-23
# 2    2000-05-04  ppp000504e.pdf 2000-05-04             2000-05-05
# 3    2000-06-07  ppp000607e.pdf 2000-06-07             2000-06-08
# 4    2000-07-06  ppp000706e.pdf 2000-07-06             2000-07-07
# 5    2000-08-16  ppp000816e.pdf 2000-08-16             2000-08-17
# 6    2000-10-24  ppp001024e.pdf 2000-10-24             2000-10-25
# 7    2000-12-20  ppp001220e.pdf 2000-12-20             2000-12-21
# 8    2001-02-01  ppp010201e.pdf 2001-02-01             2001-02-02
# 9    2001-03-26  ppp010326e.pdf 2001-03-26             2001-03-27
# 10   2001-04-26  ppp010426e.pdf 2001-04-26             2001-04-27
# 11   2001-05-30  ppp010530e.pdf 2001-05-30             2001-05-31
# 12   2001-06-14  ppp010614e.pdf 2001-06-14             2001-06-15
# 13   2001-07-05  ppp010705e.pdf 2001-07-05             2001-07-06
# 14   2001-08-23  ppp010823e.pdf 2001-08-23             2001-08-24
# 15   2001-09-17  ppp010917e.pdf 2001-09-17             2001-09-18
# 16   2001-10-15  ppp011015e.pdf 2001-10-15             2001-10-16
# 17   2001-11-08  ppp011108e.pdf 2001-11-08             2001-11-09
# 18   2001-12-04  ppp011204e.pdf 2001-12-04             2001-12-05
# 19   2002-02-07  ppp020207e.pdf 2002-02-07             2002-02-08
# 20   2002-03-18  ppp020318e.pdf 2002-03-18             2002-03-19
# 21   2002-04-25  ppp020425e.pdf 2002-04-25             2002-04-26
# 22   2002-06-05  ppp020605e.pdf 2002-06-05             2002-06-06
# 23   2002-07-04  ppp020704e.pdf 2002-07-04             2002-07-05
# 24   2002-08-15  ppp020815e.pdf 2002-08-15             2002-08-16
# 25   2002-10-16  ppp021016e.pdf 2002-10-16             2002-10-17
# 26   2002-11-14  ppp021114e.pdf 2002-11-14             2002-11-15
# 27   2002-12-04  ppp021204e.pdf 2002-12-04             2002-12-05
# 28   2003-02-06  ppp030206e.pdf 2003-02-06             2003-02-07
# 29   2003-03-17  ppp030317e.pdf 2003-03-17             2003-03-18
# ..          ...             ...        ...                    ...
# 105  2014-09-17  ppp140917e.pdf 2014-09-17             2014-09-18
# 106  2014-11-11  ppp141111e.pdf 2014-11-11             2014-11-12
# 107  2014-12-15  ppp141215e.pdf 2014-12-15             2014-12-16
# 108  2015-02-25  ppp150225e.pdf 2015-02-25             2015-02-26
# 109  2015-05-11  ppp150511e.pdf 2015-05-11             2015-05-12
# 110  2015-07-15  ppp150715e.pdf 2015-07-15             2015-07-16
# 111  2015-09-16  ppp150916e.pdf 2015-09-16             2015-09-17
# 112  2015-11-10  ppp151110e.pdf 2015-11-10             2015-11-11
# 113  2015-12-14  ppp151214e.pdf 2015-12-14             2015-12-15
# 114  2016-02-22  ppp160222e.pdf 2016-02-22             2016-02-23
# 115  2016-05-04  ppp160504e.pdf 2016-05-04             2016-05-05
# 116  2016-07-05  ppp160705e.pdf 2016-07-05             2016-07-06
# 117  2016-09-06  ppp160906e.pdf 2016-09-06             2016-09-07
# 118  2016-10-26  ppp161026e.pdf 2016-10-26             2016-10-27
# 119  2016-12-20  ppp161220e.pdf 2016-12-20             2016-12-21
# 120  2017-02-14  ppp170214e.pdf 2017-02-14             2017-02-15
# 121  2017-04-26  ppp170426e.pdf 2017-04-26             2017-04-27
# 122  2017-07-03  ppp170703e.pdf 2017-07-03             2017-07-04
# 123  2017-09-06  ppp170906e.pdf 2017-09-06             2017-09-07
# 124  2017-10-25  ppp171025e.pdf 2017-10-25             2017-10-26
# 125  2017-12-19  ppp171219e.pdf 2017-12-19             2017-12-20
# 126  2018-02-13  ppp180213e.pdf 2018-02-13             2018-02-14
# 127  2018-04-25  ppp180425e.pdf 2018-04-25             2018-04-26
# 128  2018-07-02  ppp180702e.pdf 2018-07-02             2018-07-03
# 129  2018-09-05  ppp180905e.pdf 2018-09-05             2018-09-06
# 130  2018-10-23  ppp181023e.pdf 2018-10-23             2018-10-24
# 131  2018-12-19  ppp181219e.pdf 2018-12-19             2018-12-20
# 132  2019-02-12  ppp190212e.pdf 2019-02-12             2019-02-13
# 133  2019-04-24  ppp190424e.pdf 2019-04-24             2019-04-25
# 134  2019-07-02  ppp190702e.pdf 2019-07-02             2019-07-03
#
# [135 rows x 4 columns]

# %%
sent_df = pd.concat([sent_df, pd.Series(df_files['Date time announcement'])], axis = 1, join = 'inner')
sent_df
# Out:
#      Number of positive words  Number of negative words  Average tone ratio  \
# 0                          30                        35           -0.000822
# 1                          11                        19           -0.001847
# 2                          20                        25           -0.001100
# 3                          12                        21           -0.002571
# 4                          12                        28           -0.003221
# 5                          12                        21           -0.002571
# 6                           9                        30           -0.005189
# 7                          25                        50           -0.004305
# 8                          20                        95           -0.013296
# 9                          16                        55           -0.009266
# 10                         15                        47           -0.007098
# 11                         14                        43           -0.006956
# 12                          7                        12           -0.002885
# 13                         29                       104           -0.010075
# 14                         23                        89           -0.012891
# 15                         10                        37           -0.007357
# 16                         23                        60           -0.008109
# 17                          7                        27           -0.004091
# 18                         27                        54           -0.005180
# 19                         34                        93           -0.008319
# 20                         18                        32           -0.002974
# 21                         33                        51           -0.003403
# 22                         29                        33           -0.000972
# 23                         31                        78           -0.008739
# 24                         32                        53           -0.004657
# 25                         45                        64           -0.004191
# 26                         16                        42           -0.007168
# 27                         18                        29           -0.002810
# 28                         17                        43           -0.006096
# 29                         16                        59           -0.011054
# ..                        ...                       ...                 ...
# 105                        48                        82           -0.003083
# 106                        48                        88           -0.003787
# 107                        58                        80           -0.002263
# 108                        74                       160           -0.005844
# 109                        57                       118           -0.004944
# 110                        70                       110           -0.003301
# 111                        70                       117           -0.004484
# 112                        64                       102           -0.003100
# 113                        59                        81           -0.002238
# 114                        65                       160           -0.007035
# 115                        46                        67           -0.002135
# 116                        53                       105           -0.005404
# 117                        58                        91           -0.002847
# 118                        62                        91           -0.002442
# 119                        61                        94           -0.002348
# 120                        49                        66           -0.001587
# 121                        62                        76           -0.001325
# 122                        62                        67           -0.000546
# 123                        57                        93           -0.003502
# 124                        45                        95           -0.003780
# 125                        45                        51           -0.000536
# 126                        60                        99           -0.003434
# 127                        46                        95           -0.004789
# 128                        42                       132           -0.007486
# 129                        60                       108           -0.003982
# 130                        52                        70           -0.001669
# 131                        49                        68           -0.001914
# 132                        42                        73           -0.003899
# 133                        41                        90           -0.004223
# 134                        36                       108           -0.006428
#
#      Error in processing PDF Date time announcement
# 0                      False             2000-02-04
# 1                      False             2000-03-23
# 2                      False             2000-05-05
# 3                      False             2000-06-08
# 4                      False             2000-07-07
# 5                      False             2000-08-17
# 6                      False             2000-10-25
# 7                      False             2000-12-21
# 8                      False             2001-02-02
# 9                      False             2001-03-27
# 10                     False             2001-04-27
# 11                     False             2001-05-31
# 12                     False             2001-06-15
# 13                     False             2001-07-06
# 14                     False             2001-08-24
# 15                     False             2001-09-18
# 16                     False             2001-10-16
# 17                     False             2001-11-09
# 18                     False             2001-12-05
# 19                     False             2002-02-08
# 20                     False             2002-03-19
# 21                     False             2002-04-26
# 22                     False             2002-06-06
# 23                     False             2002-07-05
# 24                     False             2002-08-16
# 25                     False             2002-10-17
# 26                     False             2002-11-15
# 27                     False             2002-12-05
# 28                     False             2003-02-07
# 29                     False             2003-03-18
# ..                       ...                    ...
# 105                    False             2014-09-18
# 106                    False             2014-11-12
# 107                    False             2014-12-16
# 108                    False             2015-02-26
# 109                    False             2015-05-12
# 110                    False             2015-07-16
# 111                    False             2015-09-17
# 112                    False             2015-11-11
# 113                    False             2015-12-15
# 114                    False             2016-02-23
# 115                    False             2016-05-05
# 116                    False             2016-07-06
# 117                    False             2016-09-07
# 118                    False             2016-10-27
# 119                    False             2016-12-21
# 120                    False             2017-02-15
# 121                    False             2017-04-27
# 122                    False             2017-07-04
# 123                    False             2017-09-07
# 124                    False             2017-10-26
# 125                    False             2017-12-20
# 126                    False             2018-02-14
# 127                    False             2018-04-26
# 128                    False             2018-07-03
# 129                    False             2018-09-06
# 130                    False             2018-10-24
# 131                    False             2018-12-20
# 132                    False             2019-02-13
# 133                    False             2019-04-25
# 134                    False             2019-07-03
#
# [135 rows x 5 columns]

# %%
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (9,4)
plt.style.use('default')
plt.rcParams.update({'font.size': 8})
plt.rcParams['lines.markersize'] = 4

x = np.array(sent_df['Date time announcement'])
y = np.array(sent_df['Average tone ratio'])

# fit = np.polyfit(x, y, 4)
# fit_fn = poly1d(fit)
# print(fit_fn)

# x_new = np.linspace(x[0], x[-1], 50)
# y_new = f(x_new)

plt.scatter(x, y)#, 'o', x_new, y_new)
# plt.plot(x, y, fit)
plt.axhline(y = 0, color = 'r', linestyle = '-', linewidth = 0.5)
plt.show
plt.savefig('Sentiment_scatter.png')
