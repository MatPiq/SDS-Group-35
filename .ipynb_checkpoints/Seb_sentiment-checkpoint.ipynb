# %%
import PyPDF2
import requests
import numpy as np, seaborn as sns, pandas as pd
import nltk, nltk.sentiment, sklearn
import collections
# %matplotlib inline

# %%
#convert list to pd.series
#doc1_str = pd.Series([''.join(doc1)])

#Preprocessing - tokenize and lower case pdf-strings
tokenizer = nltk.tokenize.TweetTokenizer()
def preprocessing(string):
    string = string.lower()
    string = tokenizer.tokenize(string)
    return string

#Apply positive/negative sets on pdf-string
#tok_doc1 = doc1_str.apply(preprocessing)

def count_dictionary(document_elem, dictionary):
    lst = []
    for word in document_elem:
        if (word in dictionary):
            lst.append(word)
    return len(lst)

# %%
#PDF extractor script. Creates a list separated per page.
def pdf_extractor(path):
    pdf_file = open(path, 'rb')
    read_pdf = PyPDF2.PdfFileReader(pdf_file)
    number_of_pages = read_pdf.getNumPages()
    c = collections.Counter(range(number_of_pages))
    res1 = []
    for i in range(len(c)):
        page = read_pdf.getPage(i)
        page_content = page.extractText()
        res1.append(page_content)
    return res1

# %%
import requests

#Create set for negative and positive lexicon
negative = set(requests.get('http://ptrckprry.com/course/ssd/data/negative-words.txt').text.split(';;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;')[2].split('\n')[2:])
positive = set(requests.get('http://ptrckprry.com/course/ssd/data/positive-words.txt').text.split(';;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;')[2].split('\n')[2:])

# %%
import os

#Sebastian file path
basedir = r'C:\Users\sebag\Documents\GitHub\SDS Group 35\Exam_Project\Minutes_PDF'
testdir = r'C:\Users\sebag\Documents\GitHub\Exam\Test folder'

def sentiment_analysis(pos, neg, file_path):
    pos_words = []
    neg_words = []
    average_tone = []
    i = 0
    error = []
    
    for fn in os.listdir(file_path):
        try:
            print('Now treating file: ' + fn + '\nIterate: ' + str(i))
            doc = pdf_extractor(file_path + '\\' + fn)
            doc = pd.Series([''.join(doc)])
            doc = doc.apply(preprocessing)

            pos_words.append(int(count_dictionary(doc[0], pos)))
            neg_words.append(int(count_dictionary(doc[0], neg)))
            average_tone.append((pos_words[i]-neg_words[i])/len(doc[0]))
            error.append(False)  
            
            i += 1
        
        except KeyError:
            error.append(True)
            pos_words.append(np.NaN)
            neg_words.append(np.NaN)
            average_tone.append(np.NaN)
            
            i += 1
            
        #date = re.findall(r'\d+', fn)
    df = pd.DataFrame(zip(error, pos_words, neg_words, average_tone, error))
    return df

sent_df = sentiment_analysis(positive, negative, basedir)
sent_df
# Out:
# Now treating file: ppp000203e.pdf
# Iterate: 0
# Now treating file: ppp000322e.pdf
# Iterate: 1
# Now treating file: ppp000504e.pdf
# Iterate: 2
# Now treating file: ppp000607e.pdf
# Iterate: 3
# Now treating file: ppp000706e.pdf
# Iterate: 4
# Now treating file: ppp000816e.pdf
# Iterate: 5
# Now treating file: ppp001024e.pdf
# Iterate: 6
# Now treating file: ppp001220e.pdf
# Iterate: 7
# Now treating file: ppp010201e.pdf
# Iterate: 8
# Now treating file: ppp010326e.pdf
# Iterate: 9
# Now treating file: ppp010426e.pdf
# Iterate: 10
# Now treating file: ppp010530e.pdf
# Iterate: 11
# Now treating file: ppp010614e.pdf
# Iterate: 12
# Now treating file: ppp010705e.pdf
# Iterate: 13
# Now treating file: ppp010823e.pdf
# Iterate: 14
# Now treating file: ppp010917e.pdf
# Iterate: 15
# Now treating file: ppp011015e.pdf
# Iterate: 16
# Now treating file: ppp011108e.pdf
# Iterate: 17
# Now treating file: ppp011204e.pdf
# Iterate: 18
# Now treating file: ppp020207e.pdf
# Iterate: 19
# Now treating file: ppp020318e.pdf
# Iterate: 20
# Now treating file: ppp020425e.pdf
# Iterate: 21
# Now treating file: ppp020605e.pdf
# Iterate: 22
# Now treating file: ppp020704e.pdf
# Iterate: 23
# Now treating file: ppp020815e.pdf
# Iterate: 24
# Now treating file: ppp021016e.pdf
# Iterate: 25
# Now treating file: ppp021114e.pdf
# Iterate: 26
# Now treating file: ppp021204e.pdf
# Iterate: 27
# Now treating file: ppp030206e.pdf
# Iterate: 28
# Now treating file: ppp030317e.pdf
# Iterate: 29
# Now treating file: ppp030424e.pdf
# Iterate: 30
# Now treating file: ppp030604e.pdf
# Iterate: 31
# Now treating file: ppp030703e.pdf
# Iterate: 32
# Now treating file: ppp030814e.pdf
# Iterate: 33
# Now treating file: ppp031015e.pdf
# Iterate: 34
# Now treating file: ppp031204e.pdf
# Iterate: 35
# Now treating file: ppp040205e.pdf
# Iterate: 36
# Now treating file: ppp040331e.pdf
# Iterate: 37
# Now treating file: ppp040428e.pdf
# Iterate: 38
# Now treating file: ppp040527e.pdf
# Iterate: 39
# Now treating file: ppp040623e.pdf
# Iterate: 40
# Now treating file: ppp040819e.pdf
# Iterate: 41
# Now treating file: ppp041013e.pdf
# Iterate: 42
# Now treating file: ppp041208e.pdf
# Iterate: 43
# Now treating file: ppp050127e.pdf
# Iterate: 44
# Now treating file: ppp050314e.pdf
# Iterate: 45
# Now treating file: ppp050428e.pdf
# Iterate: 46
# Now treating file: ppp050620e.pdf
# Iterate: 47
# Now treating file: ppp050823e.pdf
# Iterate: 48
# Now treating file: ppp051019e.pdf
# Iterate: 49
# Now treating file: ppp051201e.pdf
# Iterate: 50
# Now treating file: ppp060119e.pdf
# Iterate: 51
# Now treating file: ppp060308e.pdf
# Iterate: 52
# Now treating file: ppp060427e.pdf
# Iterate: 53
# Now treating file: ppp060619e.pdf
# Iterate: 54
# Now treating file: ppp060829e.pdf
# Iterate: 55
# Now treating file: ppp061025e.pdf
# Iterate: 56
# Now treating file: ppp061214e.pdf
# Iterate: 57
# Now treating file: ppp070214e.pdf
# Iterate: 58
# Now treating file: ppp070329e.pdf
# Iterate: 59
# Now treating file: ppp070503e.pdf
# Iterate: 60
# Now treating file: ppp070619e.pdf
# Iterate: 61
# Now treating file: ppp070906e.pdf
# Iterate: 62
# Now treating file: ppp071029e.pdf
# Iterate: 63
# Now treating file: ppp071218e.pdf
# Iterate: 64
# Now treating file: ppp080212e.pdf
# Iterate: 65
# Now treating file: ppp080422e.pdf
# Iterate: 66
# Now treating file: ppp080702e.pdf
# Iterate: 67
# Now treating file: ppp080903e.pdf
# Iterate: 68
# Now treating file: ppp081008e.pdf
# Iterate: 69
# Now treating file: ppp081022e.pdf
# Iterate: 70
# Now treating file: ppp081203e.pdf
# Iterate: 71
# Now treating file: ppp090210e.pdf
# Iterate: 72
# Now treating file: ppp090420e.pdf
# Iterate: 73
# Now treating file: ppp090701e.pdf
# Iterate: 74
# Now treating file: ppp090916e.pdf
# Iterate: 75
# Now treating file: ppp091021e.pdf
# Iterate: 76
# Now treating file: ppp091215e.pdf
# Iterate: 77
# Now treating file: ppp100224e.pdf
# Iterate: 78
# Now treating file: ppp100503e.pdf
# Iterate: 79
# Now treating file: ppp100630e.pdf
# Iterate: 80
# Now treating file: ppp100901e.pdf
# Iterate: 81
# Now treating file: ppp101025e.pdf
# Iterate: 82
# Now treating file: ppp101214e.pdf
# Iterate: 83
# Now treating file: ppp110214e.pdf
# Iterate: 84
# Now treating file: ppp110419e.pdf
# Iterate: 85
# Now treating file: ppp110704e.pdf
# Iterate: 86
# Now treating file: ppp110920e.pdf
# Iterate: 87
# Now treating file: ppp111026e.pdf
# Iterate: 88
# Now treating file: ppp111219e.pdf
# Iterate: 89
# Now treating file: ppp120215e.pdf
# Iterate: 90
# Now treating file: ppp120417e.pdf
# Iterate: 91
# Now treating file: ppp120703e.pdf
# Iterate: 92
# Now treating file: ppp120905e.pdf
# Iterate: 93
# Now treating file: ppp121024e.pdf
# Iterate: 94
# Now treating file: ppp121217e.pdf
# Iterate: 95
# Now treating file: ppp130212e.pdf
# Iterate: 96
# Now treating file: ppp130429e.pdf
# Iterate: 97
# Now treating file: ppp130716e.pdf
# Iterate: 98
# Now treating file: ppp130918e.pdf
# Iterate: 99
# Now treating file: ppp131106e.pdf
# Iterate: 100
# Now treating file: ppp131216e.pdf
# Iterate: 101
# Now treating file: ppp140212e.pdf
# Iterate: 102
# Now treating file: ppp140408e.pdf
# Iterate: 103
# Now treating file: ppp140702e.pdf
# Iterate: 104
# Now treating file: ppp140917e.pdf
# Iterate: 105
# Now treating file: ppp141111e.pdf
# Iterate: 106
# Now treating file: ppp141215e.pdf
# Iterate: 107
# Now treating file: ppp150225e.pdf
# Iterate: 108
# Now treating file: ppp150511e.pdf
# Iterate: 109
# Now treating file: ppp150715e.pdf
# Iterate: 110
# Now treating file: ppp150916e.pdf
# Iterate: 111
# Now treating file: ppp151110e.pdf
# Iterate: 112
# Now treating file: ppp151214e.pdf
# Iterate: 113
# Now treating file: ppp160104e.pdf
# Iterate: 114
# Now treating file: ppp160119e.pdf
# Iterate: 115
# Now treating file: ppp160222e.pdf
# Iterate: 116
# Now treating file: ppp160504e.pdf
# Iterate: 117
# Now treating file: ppp160705e.pdf
# Iterate: 118
# Now treating file: ppp160906e.pdf
# Iterate: 119
# Now treating file: ppp161026e.pdf
# Iterate: 120
# Now treating file: ppp161220e.pdf
# Iterate: 121
# Now treating file: ppp170214e.pdf
# Iterate: 122
# Now treating file: ppp170426e.pdf
# Iterate: 123
# Now treating file: ppp170703e.pdf
# Iterate: 124
# Now treating file: ppp170906e.pdf
# Iterate: 125
# Now treating file: ppp171025e.pdf
# Iterate: 126
# Now treating file: ppp171219e.pdf
# Iterate: 127
# Now treating file: ppp180213e.pdf
# Iterate: 128
# Now treating file: ppp180425e.pdf
# Iterate: 129
# Now treating file: ppp180702e.pdf
# Iterate: 130
# Now treating file: ppp180905e.pdf
# Iterate: 131
# Now treating file: ppp181023e.pdf
# Iterate: 132
# Now treating file: ppp181219e.pdf
# Iterate: 133
# Now treating file: ppp190212e.pdf
# Iterate: 134
# Now treating file: ppp190424e.pdf
# Iterate: 135
# Now treating file: ppp190702e.pdf
# Iterate: 136
#          0      1      2         3
# 0    False  122.0   85.0  0.006086
# 1    False   70.0   41.0  0.006694
# 2    False   70.0   48.0  0.004838
# 3    False   58.0   51.0  0.001999
# 4    False   76.0   64.0  0.002416
# 5    False   58.0   51.0  0.001999
# 6    False   58.0   61.0 -0.000741
# 7    False  113.0  143.0 -0.005166
# 8    False   85.0  118.0 -0.005850
# 9    False   55.0  110.0 -0.013067
# 10   False   51.0   79.0 -0.006211
# 11   False   58.0   83.0 -0.005997
# 12   False   29.0   31.0 -0.001154
# 13   False  118.0  189.0 -0.009538
# 14   False   86.0  132.0 -0.008984
# 15   False   56.0   93.0 -0.010082
# 16   False   82.0  130.0 -0.010519
# 17   False   58.0   51.0  0.001432
# 18   False   85.0  107.0 -0.004221
# 19   False  119.0  186.0 -0.009447
# 20   False   70.0   88.0 -0.003823
# 21   False   78.0  108.0 -0.005671
# 22   False   58.0   72.0 -0.003403
# 23   False   89.0  169.0 -0.014875
# 24   False   82.0  106.0 -0.005323
# 25   False   92.0  129.0 -0.008162
# 26   False   54.0   99.0 -0.012407
# 27   False   53.0   67.0 -0.003577
# 28   False   57.0   96.0 -0.009144
# 29   False   62.0  116.0 -0.013882
# ..     ...    ...    ...       ...
# 107  False  160.0  203.0 -0.004423
# 108   True    NaN    NaN       NaN
# 109   True    NaN    NaN       NaN
# 110   True    NaN    NaN       NaN
# 111   True    NaN    NaN       NaN
# 112  False  238.0  203.0  0.002855
# 113   True    NaN    NaN       NaN
# 114  False    1.0    0.0  0.003300
# 115  False    1.0    1.0  0.000000
# 116  False  294.0  277.0  0.001259
# 117  False  198.0  174.0  0.002440
# 118  False  203.0  173.0  0.003118
# 119   True    NaN    NaN       NaN
# 120   True    NaN    NaN       NaN
# 121  False  277.0  236.0  0.002917
# 122   True    NaN    NaN       NaN
# 123  False  210.0  182.0  0.002650
# 124   True    NaN    NaN       NaN
# 125  False  222.0  192.0  0.002918
# 126  False  259.0  236.0  0.001739
# 127   True    NaN    NaN       NaN
# 128  False  243.0  197.0  0.004050
# 129  False  192.0  180.0  0.001173
# 130  False  210.0  244.0 -0.002828
# 131  False  255.0  208.0  0.003899
# 132   True    NaN    NaN       NaN
# 133   True    NaN    NaN       NaN
# 134  False  152.0  152.0  0.000000
# 135  False  212.0  184.0  0.002413
# 136  False  195.0  209.0 -0.001250
#
# [137 rows x 4 columns]

# %%
sent_df.columns = ['Number of positive words', 'Number of negative words', 'Average tone ratio', 'Error in processing PDF']
print(sent_df.loc[sent_df['Number of positive words'] == True])
#sent_df
# Out:
#      Number of positive words  Number of negative words  Average tone ratio  \
# 94                       True                       NaN                 NaN
# 95                       True                       NaN                 NaN
# 96                       True                       NaN                 NaN
# 97                       True                       NaN                 NaN
# 98                       True                       NaN                 NaN
# 100                      True                       NaN                 NaN
# 101                      True                       NaN                 NaN
# 102                      True                       NaN                 NaN
# 103                      True                       NaN                 NaN
# 104                      True                       NaN                 NaN
# 105                      True                       NaN                 NaN
# 106                      True                       NaN                 NaN
# 108                      True                       NaN                 NaN
# 109                      True                       NaN                 NaN
# 110                      True                       NaN                 NaN
# 111                      True                       NaN                 NaN
# 113                      True                       NaN                 NaN
# 119                      True                       NaN                 NaN
# 120                      True                       NaN                 NaN
# 122                      True                       NaN                 NaN
# 124                      True                       NaN                 NaN
# 127                      True                       NaN                 NaN
# 132                      True                       NaN                 NaN
# 133                      True                       NaN                 NaN
#
#      Error in processing PDF
# 94                       NaN
# 95                       NaN
# 96                       NaN
# 97                       NaN
# 98                       NaN
# 100                      NaN
# 101                      NaN
# 102                      NaN
# 103                      NaN
# 104                      NaN
# 105                      NaN
# 106                      NaN
# 108                      NaN
# 109                      NaN
# 110                      NaN
# 111                      NaN
# 113                      NaN
# 119                      NaN
# 120                      NaN
# 122                      NaN
# 124                      NaN
# 127                      NaN
# 132                      NaN
# 133                      NaN

# %%
pos_words = []
doc = pdf_extractor(r'C:\Users\sebag\Documents\GitHub\SDS Group 35\Exam_Project\Minutes_PDF\ppp000203e.pdf')
doc = pd.Series([''.join(doc)])
doc = doc.apply(preprocessing)
count_dictionary(doc[0], negative)
pos_words.append(count_dictionary(doc[0], positive))
print(pos_words)
print(len(doc[0]))
# Out:
# [122]
# 6080

# %%
pos_words = []
neg_words = []
average_tone = []
i = 0

for fn in os.listdir(testdir):
    doc = pdf_extractor(testdir + '\\' + fn)
    doc = pd.Series([''.join(doc)])
    doc = doc.apply(preprocessing)
    pos_words.append(count_dictionary(doc[0], positive))
    neg_words.append(count_dictionary(doc[0], negative))
    average_tone = (pos_words[i]-neg_words[i])/len(doc[0])
        
    i += 1
    #date = re.findall(r'\d+', fn)
df = pd.DataFrame(zip(pos_words, neg_words, average_tone))
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-09c714f1a030> in <module>
#      15     i += 1
#      16     #date = re.findall(r'\d+', fn)
# ---> 17 df = pd.DataFrame(zip(pos_words, neg_words, average_tone))
#      18 df
#
# TypeError: zip argument #3 must support iteration

# %%
import os, re, pandas as pd, ast, datetime

#Mark file path:
path = 'C:/Users/maje.DKSUND/Desktop/SDS-Group-35-master_new/SDS-Group-35-master/Exam_Project/Minutes_PDF'

files = []
files2 = []

# r=root, d=directories, f = files
for r, d, f in os.walk(basedir):
    for file in f:
        if '.pdf' in file:
            files.append(file[7:9] + "-" + file[5:7] + "-" + file[3:5])
            files2.append(file)

Final_list = {'Dato':files,'Filnavn':files2}

df_files = pd.DataFrame(Final_list)
df_files['date_time'] = pd.to_datetime(df_files['Dato'])
df_files['date_time_announcement'] = pd.to_datetime(df_files['Dato']) + pd.DateOffset(days=1)
df_files
# Out:
#          Dato         Filnavn  date_time date_time_announcement
# 0    03-02-00  ppp000203e.pdf 2000-03-02             2000-03-03
# 1    22-03-00  ppp000322e.pdf 2000-03-22             2000-03-23
# 2    04-05-00  ppp000504e.pdf 2000-04-05             2000-04-06
# 3    07-06-00  ppp000607e.pdf 2000-07-06             2000-07-07
# 4    06-07-00  ppp000706e.pdf 2000-06-07             2000-06-08
# 5    16-08-00  ppp000816e.pdf 2000-08-16             2000-08-17
# 6    24-10-00  ppp001024e.pdf 2000-10-24             2000-10-25
# 7    20-12-00  ppp001220e.pdf 2000-12-20             2000-12-21
# 8    01-02-01  ppp010201e.pdf 2001-01-02             2001-01-03
# 9    26-03-01  ppp010326e.pdf 2001-03-26             2001-03-27
# 10   26-04-01  ppp010426e.pdf 2001-04-26             2001-04-27
# 11   30-05-01  ppp010530e.pdf 2001-05-30             2001-05-31
# 12   14-06-01  ppp010614e.pdf 2001-06-14             2001-06-15
# 13   05-07-01  ppp010705e.pdf 2001-05-07             2001-05-08
# 14   23-08-01  ppp010823e.pdf 2001-08-23             2001-08-24
# 15   17-09-01  ppp010917e.pdf 2001-09-17             2001-09-18
# 16   15-10-01  ppp011015e.pdf 2001-10-15             2001-10-16
# 17   08-11-01  ppp011108e.pdf 2001-08-11             2001-08-12
# 18   04-12-01  ppp011204e.pdf 2001-04-12             2001-04-13
# 19   07-02-02  ppp020207e.pdf 2002-07-02             2002-07-03
# 20   18-03-02  ppp020318e.pdf 2002-03-18             2002-03-19
# 21   25-04-02  ppp020425e.pdf 2002-04-25             2002-04-26
# 22   05-06-02  ppp020605e.pdf 2002-05-06             2002-05-07
# 23   04-07-02  ppp020704e.pdf 2002-04-07             2002-04-08
# 24   15-08-02  ppp020815e.pdf 2002-08-15             2002-08-16
# 25   16-10-02  ppp021016e.pdf 2002-10-16             2002-10-17
# 26   14-11-02  ppp021114e.pdf 2002-11-14             2002-11-15
# 27   04-12-02  ppp021204e.pdf 2002-04-12             2002-04-13
# 28   06-02-03  ppp030206e.pdf 2003-06-02             2003-06-03
# 29   17-03-03  ppp030317e.pdf 2003-03-17             2003-03-18
# ..        ...             ...        ...                    ...
# 107  15-12-14  ppp141215e.pdf 2014-12-15             2014-12-16
# 108  25-02-15  ppp150225e.pdf 2015-02-25             2015-02-26
# 109  11-05-15  ppp150511e.pdf 2015-11-05             2015-11-06
# 110  15-07-15  ppp150715e.pdf 2015-07-15             2015-07-16
# 111  16-09-15  ppp150916e.pdf 2015-09-16             2015-09-17
# 112  10-11-15  ppp151110e.pdf 2015-10-11             2015-10-12
# 113  14-12-15  ppp151214e.pdf 2015-12-14             2015-12-15
# 114  04-01-16  ppp160104e.pdf 2016-04-01             2016-04-02
# 115  19-01-16  ppp160119e.pdf 2016-01-19             2016-01-20
# 116  22-02-16  ppp160222e.pdf 2016-02-22             2016-02-23
# 117  04-05-16  ppp160504e.pdf 2016-04-05             2016-04-06
# 118  05-07-16  ppp160705e.pdf 2016-05-07             2016-05-08
# 119  06-09-16  ppp160906e.pdf 2016-06-09             2016-06-10
# 120  26-10-16  ppp161026e.pdf 2016-10-26             2016-10-27
# 121  20-12-16  ppp161220e.pdf 2016-12-20             2016-12-21
# 122  14-02-17  ppp170214e.pdf 2017-02-14             2017-02-15
# 123  26-04-17  ppp170426e.pdf 2017-04-26             2017-04-27
# 124  03-07-17  ppp170703e.pdf 2017-03-07             2017-03-08
# 125  06-09-17  ppp170906e.pdf 2017-06-09             2017-06-10
# 126  25-10-17  ppp171025e.pdf 2017-10-25             2017-10-26
# 127  19-12-17  ppp171219e.pdf 2017-12-19             2017-12-20
# 128  13-02-18  ppp180213e.pdf 2018-02-13             2018-02-14
# 129  25-04-18  ppp180425e.pdf 2018-04-25             2018-04-26
# 130  02-07-18  ppp180702e.pdf 2018-02-07             2018-02-08
# 131  05-09-18  ppp180905e.pdf 2018-05-09             2018-05-10
# 132  23-10-18  ppp181023e.pdf 2018-10-23             2018-10-24
# 133  19-12-18  ppp181219e.pdf 2018-12-19             2018-12-20
# 134  12-02-19  ppp190212e.pdf 2019-12-02             2019-12-03
# 135  24-04-19  ppp190424e.pdf 2019-04-24             2019-04-25
# 136  02-07-19  ppp190702e.pdf 2019-02-07             2019-02-08
#
# [137 rows x 4 columns]
